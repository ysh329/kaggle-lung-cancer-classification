# %%
# %matplotlib inline

import numpy as np
import dicom
import glob
from matplotlib import pyplot as plt
import os
import cv2
import mxnet as mx
import pandas as pd

# %%
from sklearn import cross_validation
import xgboost as xgb
# Out:
# /usr/local/lib/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def get_extractor():
    model = mx.model.FeedForward.load('/home/yuens/Downloads/code/mxnet_inference/resnet/resnet-50',\
                                      0, ctx=mx.cpu(), numpy_batch_size=1)
    # model.symbol.get_internals: 
    # Get a new grouped symbol whose output contains internal outputs of this symbol.
    fea_symbol = model.symbol.get_internals()["flatten0_output"]
    feature_extractor = mx.model.FeedForward(ctx=mx.cpu(), symbol=fea_symbol, numpy_batch_size=64,
                                             arg_params=model.arg_params, aux_params=model.aux_params,
                                             allow_extra_params=True)

    return feature_extractor

# %%
def get_3d_data(path):
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key=lambda x: int(x.InstanceNumber))
    return np.stack([s.pixel_array for s in slices])

# %%
# 得到当前path路径的病人的所有图像序列
def get_data_id(path):
    sample_image = get_3d_data(path)
    sample_image[sample_image == -2000] = 0
    # f, plots = plt.subplots(4, 5, sharex='col', sharey='row', figsize=(10, 8))

    batch = []
    cnt = 0
    dx = 40
    ds = 512
    # 这里不是resampling而是遍历每个图像做
    for i in range(0, sample_image.shape[0] - 3, 3):
        # 每个tmp是三幅2D图像
        tmp = []
        for j in range(3):
            img = sample_image[i + j]
            img = 255.0 / np.amax(img) * img
            # 直方图均衡化
            img = cv2.equalizeHist(img.astype(np.uint8))
            img = img[dx: ds - dx, dx: ds - dx]
            img = cv2.resize(img, (224, 224))
            tmp.append(img)
        # 每个tmp是三幅2D图像把结果追加保存到batch列表
        # tmp是3D的
        # batch是4D的(第i捆三张打包，三张打包中的第j张，第j张的第k行，第j张的第m列)
        tmp = np.array(tmp)
        batch.append(np.array(tmp))

        # if cnt < 20:
        #     plots[cnt // 5, cnt % 5].axis('off')
        #     plots[cnt // 5, cnt % 5].imshow(np.swapaxes(tmp, 0, 2))
        # cnt += 1

    # plt.show()
    # 整个batch再次转化为numpy
    batch = np.array(batch)
    return batch

# %%
def calc_features():
    # 加载网络模型和参数
    net = get_extractor()
    # 逐个遍历病人
    # 获取当前病人的所有CT图像序列
    # 根据图像序列给网络做预测
    # 打印特征维度并将特征保存为np形式
    patients_folder_path = glob.glob('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1/*')
    print("len(patients_folder_path):{0}".format(len(patients_folder_path)))
    for idx in xrange(len(patients_folder_path[:10])):
        print(idx, patients_folder_path[idx]) 
    
    valid_pathients_folder_path = filter(lambda p: ".npy" not in p, patients_folder_path)
    extracted_patients_npy_folder_path = filter(lambda p: ".npy" in p, patients_folder_path)
    extracted_patients_folder_path = map(lambda p: p.replace(".npy", ""), extracted_patients_npy_folder_path)
    unextracted_patients_folder_path = filter(lambda p: p not in extracted_patients_folder_path, valid_pathients_folder_path)
    print("len(valid_pathients_folder_path):{0}".format(len(valid_pathients_folder_path)))
    for idx in xrange(len(valid_pathients_folder_path[:10])):
        print(idx, valid_pathients_folder_path[idx]) 
    
    print("len(unextracted_patients_folder_path):{0}".format(len(unextracted_patients_folder_path)))
    for idx in xrange(len(unextracted_patients_folder_path[:10])):
        print(idx, unextracted_patients_folder_path[idx])
        
        
    print("len(extracted_patients_folder_path):{0}".format(len(extracted_patients_folder_path)))
    for idx in xrange(len(extracted_patients_folder_path[:10])):
        print(idx, extracted_patients_folder_path[idx])
    
    for idx in xrange(len(unextracted_patients_folder_path)):
        folder_path = unextracted_patients_folder_path[idx]
        batch = get_data_id(folder_path)
        feats = net.predict(batch)
        print(idx,feats.shape)
        np.save(folder_path, feats)

# %%
def train_xgboost():
    import time
    df = pd.read_csv('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1_labels.csv')
    print(df.head())
    
    x = np.array([np.mean(np.load('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/npy_files/%s.npy' % str(id)),\
                          axis=0) for id in df['id'].tolist()]\
                )
    
    y = df['cancer'].as_matrix()

    trn_x, val_x, trn_y, val_y = cross_validation.train_test_split(x, y, random_state=42, stratify=y,
                                                                   test_size=0.20)#0.20

    clf = xgb.XGBRegressor(max_depth=10,
                           n_estimators=10500,
                           min_child_weight=9,
                           learning_rate=0.0005,
                           nthread=8,
                           subsample=0.80,#0.8
                           colsample_bytree=0.80,
                           seed=4242)

    clf.fit(trn_x, trn_y, eval_set=[(val_x, val_y)],\
            verbose=True,\
            eval_metric='logloss',\
            early_stopping_rounds=250)
    # eval_metric='logloss' or 'error' 
    
#     # 输出模型验证集上的分类性能、
#     train_predictions = clf.predict(val_x)
#     #train_predprob = clf.predict_proba(train_x)#[:,1] #1的概率
#     print("\nModel Report")
#     print("val set")
#     print train_predictions
#     #print("AUC Score (Train): %f" % metrics.roc_auc_score(val_y, train_predprob))
    
#     # 训练集性呢过
#     print("train set")
#     train_predictions = clf.predict(trn_x)
#     #train_predprob = clf.predict_proba(trn_x)#[:,1] #1的概率
#     print("train set in train")
#     #print("Accuracy : %.4g" % metrics.accuracy_score(trn_y, train_predictions))
#     #print("AUC Score (Train): %f" % metrics.roc_auc_score(trn_y, train_predprob))
    
    return clf

# %%
def make_submit():
    clf = train_xgboost()
    
    # 取出测试集数据做预测
    df = pd.read_csv('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1_sample_submission.csv')
    x = np.array([np.mean(np.load('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/npy_files/%s.npy' % str(id)), axis=0) for id in df['id'].tolist()])
    pred = clf.predict(x)

    # 取出训练集预测
#     df = pd.read_csv('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1_labels.csv')
#     x = np.array([np.mean(np.load('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/npy_files/%s.npy' % str(id)), axis=0) for id in df['id'].tolist()])
#     pred = clf.predict(x)

    # 将结果写入文件准备提交
    df['cancer'] = pred
    df.to_csv('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/[mxnet+xgb]submit_metrics_logloss_axis_0_earlystopping_250_lr_0.0005.csv', index=False)
    print(df.head())

# %%
if __name__ == '__main__':
    # 单个特征的提取时间大概是50s左右
    #calc_features()
    import pandas as pd
    import numpy as np
    make_submit()
# Out:
#                                  id  cancer
# 0  0015ceb851d7251b8f399e39779d1e7d       1
# 1  0030a160d58723ff36d73f41b170ec21       0
# 2  003f41c78e6acfa92430a057ac0b306e       0
# 3  006b96310a37b36cccb2ab48d10b49a3       1
# 4  008464bb8521d09a42985dd8add3d0d2       1
# [0]	validation_0-logloss:0.693053
# Will train until validation_0-logloss hasn't improved in 250 rounds.
# [1]	validation_0-logloss:0.692931
# [2]	validation_0-logloss:0.692825
# [3]	validation_0-logloss:0.692723
# [4]	validation_0-logloss:0.692578
# [5]	validation_0-logloss:0.692447
# [6]	validation_0-logloss:0.692326
# [7]	validation_0-logloss:0.692178
# [8]	validation_0-logloss:0.692065
# [9]	validation_0-logloss:0.691945
# [10]	validation_0-logloss:0.691818
# [11]	validation_0-logloss:0.691694
# [12]	validation_0-logloss:0.691602
# [13]	validation_0-logloss:0.691482
# [14]	validation_0-logloss:0.691363
# [15]	validation_0-logloss:0.691257
# [16]	validation_0-logloss:0.691136
# [17]	validation_0-logloss:0.691021
# [18]	validation_0-logloss:0.690867
# [19]	validation_0-logloss:0.690757
# [20]	validation_0-logloss:0.690625
# [21]	validation_0-logloss:0.690528
# [22]	validation_0-logloss:0.690413
# [23]	validation_0-logloss:0.690307
# [24]	validation_0-logloss:0.690164
# [25]	validation_0-logloss:0.690053
# [26]	validation_0-logloss:0.689946
# [27]	validation_0-logloss:0.689804
# [28]	validation_0-logloss:0.689625
# [29]	validation_0-logloss:0.689491
# [30]	validation_0-logloss:0.689376
# [31]	validation_0-logloss:0.689263
# [32]	validation_0-logloss:0.689101
# [33]	validation_0-logloss:0.688999
# [34]	validation_0-logloss:0.688888
# [35]	validation_0-logloss:0.688781
# [36]	validation_0-logloss:0.688651
# [37]	validation_0-logloss:0.68854
# [38]	validation_0-logloss:0.688393
# [39]	validation_0-logloss:0.688273
# [40]	validation_0-logloss:0.688166
# [41]	validation_0-logloss:0.688057
# [42]	validation_0-logloss:0.687938
# [43]	validation_0-logloss:0.687843
# [44]	validation_0-logloss:0.687714
# [45]	validation_0-logloss:0.687592
# [46]	validation_0-logloss:0.687485
# [47]	validation_0-logloss:0.687358
# [48]	validation_0-logloss:0.687227
# [49]	validation_0-logloss:0.68711
# [50]	validation_0-logloss:0.687008
# [51]	validation_0-logloss:0.686906
# [52]	validation_0-logloss:0.686793
# [53]	validation_0-logloss:0.686664
# [54]	validation_0-logloss:0.686547
# [55]	validation_0-logloss:0.686439
# [56]	validation_0-logloss:0.686322
# [57]	validation_0-logloss:0.686197
# [58]	validation_0-logloss:0.686065
# [59]	validation_0-logloss:0.685933
# [60]	validation_0-logloss:0.685821
# [61]	validation_0-logloss:0.685688
# [62]	validation_0-logloss:0.685586
# [63]	validation_0-logloss:0.685479
# [64]	validation_0-logloss:0.685374
# [65]	validation_0-logloss:0.685277
# [66]	validation_0-logloss:0.685163
# [67]	validation_0-logloss:0.685056
# [68]	validation_0-logloss:0.684942
# [69]	validation_0-logloss:0.684805
# [70]	validation_0-logloss:0.684656
# [71]	validation_0-logloss:0.684532
# [72]	validation_0-logloss:0.684411
# [73]	validation_0-logloss:0.684301
# [74]	validation_0-logloss:0.684163
# [75]	validation_0-logloss:0.68404
# [76]	validation_0-logloss:0.683915
# [77]	validation_0-logloss:0.683839
# [78]	validation_0-logloss:0.683723
# [79]	validation_0-logloss:0.683585
# [80]	validation_0-logloss:0.683445
# [81]	validation_0-logloss:0.683369
# [82]	validation_0-logloss:0.683269
# [83]	validation_0-logloss:0.683153
# [84]	validation_0-logloss:0.683039
# [85]	validation_0-logloss:0.68292
# [86]	validation_0-logloss:0.682801
# [87]	validation_0-logloss:0.682679
# [88]	validation_0-logloss:0.682545
# [89]	validation_0-logloss:0.682435
# [90]	validation_0-logloss:0.682297
# [91]	validation_0-logloss:0.682226
# [92]	validation_0-logloss:0.682121
# [93]	validation_0-logloss:0.682001
# [94]	validation_0-logloss:0.681885
# [95]	validation_0-logloss:0.681795
# [96]	validation_0-logloss:0.681712
# [97]	validation_0-logloss:0.681599
# [98]	validation_0-logloss:0.681494
# [99]	validation_0-logloss:0.681376
# [100]	validation_0-logloss:0.681269
# [101]	validation_0-logloss:0.681144
# [102]	validation_0-logloss:0.681028
# [103]	validation_0-logloss:0.680909
# [104]	validation_0-logloss:0.680793
# [105]	validation_0-logloss:0.680692
# [106]	validation_0-logloss:0.68058
# [107]	validation_0-logloss:0.68051
# [108]	validation_0-logloss:0.680403
# [109]	validation_0-logloss:0.680267
# [110]	validation_0-logloss:0.680144
# [111]	validation_0-logloss:0.680036
# [112]	validation_0-logloss:0.679918
# [113]	validation_0-logloss:0.67979
# [114]	validation_0-logloss:0.679683
# [115]	validation_0-logloss:0.679608
# [116]	validation_0-logloss:0.679477
# [117]	validation_0-logloss:0.679372
# [118]	validation_0-logloss:0.679282
# [119]	validation_0-logloss:0.6792
# [120]	validation_0-logloss:0.679101
# [121]	validation_0-logloss:0.678986
# [122]	validation_0-logloss:0.678874
# [123]	validation_0-logloss:0.678751
# [124]	validation_0-logloss:0.678639
# [125]	validation_0-logloss:0.678535
# [126]	validation_0-logloss:0.678435
# [127]	validation_0-logloss:0.678336
# [128]	validation_0-logloss:0.678248
# [129]	validation_0-logloss:0.678162
# [130]	validation_0-logloss:0.678055
# [131]	validation_0-logloss:0.677938
# [132]	validation_0-logloss:0.677814
# [133]	validation_0-logloss:0.677703
# [134]	validation_0-logloss:0.677605
# [135]	validation_0-logloss:0.677526
# [136]	validation_0-logloss:0.677427
# [137]	validation_0-logloss:0.677311
# [138]	validation_0-logloss:0.677186
# [139]	validation_0-logloss:0.677082
# [140]	validation_0-logloss:0.676963
# [141]	validation_0-logloss:0.676861
# [142]	validation_0-logloss:0.67676
# [143]	validation_0-logloss:0.676633
# [144]	validation_0-logloss:0.676544
# [145]	validation_0-logloss:0.676439
# [146]	validation_0-logloss:0.676356
# [147]	validation_0-logloss:0.676242
# [148]	validation_0-logloss:0.676165
# [149]	validation_0-logloss:0.676048
# [150]	validation_0-logloss:0.675925
# [151]	validation_0-logloss:0.675804
# [152]	validation_0-logloss:0.67569
# [153]	validation_0-logloss:0.675586
# [154]	validation_0-logloss:0.675466
# [155]	validation_0-logloss:0.675348
# [156]	validation_0-logloss:0.675265
# [157]	validation_0-logloss:0.67513
# [158]	validation_0-logloss:0.675026
# [159]	validation_0-logloss:0.674938
# [160]	validation_0-logloss:0.674854
# [161]	validation_0-logloss:0.674726
# [162]	validation_0-logloss:0.674618
# [163]	validation_0-logloss:0.674514
# [164]	validation_0-logloss:0.674401
# [165]	validation_0-logloss:0.674288
# [166]	validation_0-logloss:0.674158
# [167]	validation_0-logloss:0.674037
# [168]	validation_0-logloss:0.673918
# [169]	validation_0-logloss:0.673805
# [170]	validation_0-logloss:0.673686
# [171]	validation_0-logloss:0.67356
# [172]	validation_0-logloss:0.673446
# [173]	validation_0-logloss:0.673336
# [174]	validation_0-logloss:0.673236
# [175]	validation_0-logloss:0.673178
# [176]	validation_0-logloss:0.673041
# [177]	validation_0-logloss:0.67292
# [178]	validation_0-logloss:0.67282
# [179]	validation_0-logloss:0.672715
# [180]	validation_0-logloss:0.672633
# [181]	validation_0-logloss:0.672531
# [182]	validation_0-logloss:0.672434
# [183]	validation_0-logloss:0.672336
# [184]	validation_0-logloss:0.672234
# [185]	validation_0-logloss:0.672104
# [186]	validation_0-logloss:0.671982
# [187]	validation_0-logloss:0.671889
# [188]	validation_0-logloss:0.671762
# [189]	validation_0-logloss:0.671657
# [190]	validation_0-logloss:0.671526
# [191]	validation_0-logloss:0.671446
# [192]	validation_0-logloss:0.671369
# [193]	validation_0-logloss:0.671264
# [194]	validation_0-logloss:0.671138
# [195]	validation_0-logloss:0.671015
# [196]	validation_0-logloss:0.670884
# [197]	validation_0-logloss:0.670776
# [198]	validation_0-logloss:0.670681
# [199]	validation_0-logloss:0.670576
# [200]	validation_0-logloss:0.670471
# [201]	validation_0-logloss:0.670344
# [202]	validation_0-logloss:0.670227
# [203]	validation_0-logloss:0.670117
# [204]	validation_0-logloss:0.67004
# [205]	validation_0-logloss:0.669929
# [206]	validation_0-logloss:0.669837
# [207]	validation_0-logloss:0.669752
# [208]	validation_0-logloss:0.669659
# [209]	validation_0-logloss:0.669558
# [210]	validation_0-logloss:0.669474
# [211]	validation_0-logloss:0.669368
# [212]	validation_0-logloss:0.669248
# [213]	validation_0-logloss:0.669157
# [214]	validation_0-logloss:0.669033
# [215]	validation_0-logloss:0.668935
# [216]	validation_0-logloss:0.668835
# [217]	validation_0-logloss:0.668721
# [218]	validation_0-logloss:0.668618
# [219]	validation_0-logloss:0.668519
# [220]	validation_0-logloss:0.668408
# [221]	validation_0-logloss:0.668315
# [222]	validation_0-logloss:0.668228
# [223]	validation_0-logloss:0.668113
# [224]	validation_0-logloss:0.66802
# [225]	validation_0-logloss:0.66789
# [226]	validation_0-logloss:0.667791
# [227]	validation_0-logloss:0.667629
# [228]	validation_0-logloss:0.66753
# [229]	validation_0-logloss:0.667454
# [230]	validation_0-logloss:0.6674
# [231]	validation_0-logloss:0.667293
# [232]	validation_0-logloss:0.667228
# [233]	validation_0-logloss:0.667121
# [234]	validation_0-logloss:0.667019
# [235]	validation_0-logloss:0.666937
# [236]	validation_0-logloss:0.666852
# [237]	validation_0-logloss:0.666779
# [238]	validation_0-logloss:0.66667
# [239]	validation_0-logloss:0.666569
# [240]	validation_0-logloss:0.666464
# [241]	validation_0-logloss:0.666342
# [242]	validation_0-logloss:0.666252
# [243]	validation_0-logloss:0.666185
# [244]	validation_0-logloss:0.666091
# [245]	validation_0-logloss:0.665985
# [246]	validation_0-logloss:0.66586
# [247]	validation_0-logloss:0.665764
# [248]	validation_0-logloss:0.665688
# [249]	validation_0-logloss:0.665572
# [250]	validation_0-logloss:0.665498
# [251]	validation_0-logloss:0.665402
# [252]	validation_0-logloss:0.665326
# [253]	validation_0-logloss:0.665227
# [254]	validation_0-logloss:0.665125
# [255]	validation_0-logloss:0.66502
# [256]	validation_0-logloss:0.664926
# [257]	validation_0-logloss:0.664808
# [258]	validation_0-logloss:0.664733
# [259]	validation_0-logloss:0.664639
# [260]	validation_0-logloss:0.664573
# [261]	validation_0-logloss:0.664496
# [262]	validation_0-logloss:0.664427
# [263]	validation_0-logloss:0.664319
# [264]	validation_0-logloss:0.664207
# [265]	validation_0-logloss:0.664135
# [266]	validation_0-logloss:0.664044
# [267]	validation_0-logloss:0.663948
# [268]	validation_0-logloss:0.66387
# [269]	validation_0-logloss:0.663769
# [270]	validation_0-logloss:0.663692
# [271]	validation_0-logloss:0.663598
# [272]	validation_0-logloss:0.663503
# [273]	validation_0-logloss:0.663433
# [274]	validation_0-logloss:0.663347
# [275]	validation_0-logloss:0.663242
# [276]	validation_0-logloss:0.663145
# [277]	validation_0-logloss:0.663035
# [278]	validation_0-logloss:0.662957
# [279]	validation_0-logloss:0.662862
# [280]	validation_0-logloss:0.662778
# [281]	validation_0-logloss:0.662688
# [282]	validation_0-logloss:0.662589
# [283]	validation_0-logloss:0.662491
# [284]	validation_0-logloss:0.662381
# [285]	validation_0-logloss:0.662271
# [286]	validation_0-logloss:0.662166
# [287]	validation_0-logloss:0.662084
# [288]	validation_0-logloss:0.66199
# [289]	validation_0-logloss:0.661901
# [290]	validation_0-logloss:0.661795
# [291]	validation_0-logloss:0.661711
# [292]	validation_0-logloss:0.661607
# [293]	validation_0-logloss:0.661509
# [294]	validation_0-logloss:0.661393
# [295]	validation_0-logloss:0.661326
# [296]	validation_0-logloss:0.661254
# [297]	validation_0-logloss:0.661137
# [298]	validation_0-logloss:0.661033
# [299]	validation_0-logloss:0.660923
# [300]	validation_0-logloss:0.660802
# [301]	validation_0-logloss:0.660697
# [302]	validation_0-logloss:0.660606
# [303]	validation_0-logloss:0.660497
# [304]	validation_0-logloss:0.660389
# [305]	validation_0-logloss:0.660296
# [306]	validation_0-logloss:0.660208
# [307]	validation_0-logloss:0.660139
# [308]	validation_0-logloss:0.660037
# [309]	validation_0-logloss:0.659934
# [310]	validation_0-logloss:0.659824
# [311]	validation_0-logloss:0.659736
# [312]	validation_0-logloss:0.659652
# [313]	validation_0-logloss:0.659573
# [314]	validation_0-logloss:0.659486
# [315]	validation_0-logloss:0.659384
# [316]	validation_0-logloss:0.659279
# [317]	validation_0-logloss:0.659205
# [318]	validation_0-logloss:0.659105
# [319]	validation_0-logloss:0.659003
# [320]	validation_0-logloss:0.658886
# [321]	validation_0-logloss:0.65879
# [322]	validation_0-logloss:0.658694
# [323]	validation_0-logloss:0.658591
# [324]	validation_0-logloss:0.658484
# [325]	validation_0-logloss:0.658392
# [326]	validation_0-logloss:0.658293
# [327]	validation_0-logloss:0.658218
# [328]	validation_0-logloss:0.658137
# [329]	validation_0-logloss:0.658054
# [330]	validation_0-logloss:0.657982
# [331]	validation_0-logloss:0.657915
# [332]	validation_0-logloss:0.657829
# [333]	validation_0-logloss:0.657747
# [334]	validation_0-logloss:0.657662
# [335]	validation_0-logloss:0.657556
# [336]	validation_0-logloss:0.657459
# [337]	validation_0-logloss:0.657371
# [338]	validation_0-logloss:0.657296
# [339]	validation_0-logloss:0.657206
# [340]	validation_0-logloss:0.657105
# [341]	validation_0-logloss:0.65704
# [342]	validation_0-logloss:0.65695
# [343]	validation_0-logloss:0.656841
# [344]	validation_0-logloss:0.65678
# [345]	validation_0-logloss:0.656678
# [346]	validation_0-logloss:0.656559
# [347]	validation_0-logloss:0.656474
# [348]	validation_0-logloss:0.656382
# [349]	validation_0-logloss:0.656303
# [350]	validation_0-logloss:0.656224
# [351]	validation_0-logloss:0.656123
# [352]	validation_0-logloss:0.656059
# [353]	validation_0-logloss:0.655968
# [354]	validation_0-logloss:0.655898
# [355]	validation_0-logloss:0.655807
# [356]	validation_0-logloss:0.655698
# [357]	validation_0-logloss:0.655609
# [358]	validation_0-logloss:0.655501
# [359]	validation_0-logloss:0.655383
# [360]	validation_0-logloss:0.655273
# [361]	validation_0-logloss:0.655211
# [362]	validation_0-logloss:0.655125
# [363]	validation_0-logloss:0.655062
# [364]	validation_0-logloss:0.654977
# [365]	validation_0-logloss:0.654904
# [366]	validation_0-logloss:0.654834
# [367]	validation_0-logloss:0.654752
# [368]	validation_0-logloss:0.654663
# [369]	validation_0-logloss:0.654576
# [370]	validation_0-logloss:0.654452
# [371]	validation_0-logloss:0.654359
# [372]	validation_0-logloss:0.654261
# [373]	validation_0-logloss:0.65419
# [374]	validation_0-logloss:0.654105
# [375]	validation_0-logloss:0.654017
# [376]	validation_0-logloss:0.653929
# [377]	validation_0-logloss:0.653841
# [378]	validation_0-logloss:0.653745
# [379]	validation_0-logloss:0.653667
# [380]	validation_0-logloss:0.653591
# [381]	validation_0-logloss:0.653515
# [382]	validation_0-logloss:0.653446
# [383]	validation_0-logloss:0.653348
# [384]	validation_0-logloss:0.653263
# [385]	validation_0-logloss:0.65317
# [386]	validation_0-logloss:0.65306
# [387]	validation_0-logloss:0.652986
# [388]	validation_0-logloss:0.652903
# [389]	validation_0-logloss:0.652813
# [390]	validation_0-logloss:0.65272
# [391]	validation_0-logloss:0.652633
# [392]	validation_0-logloss:0.652544
# [393]	validation_0-logloss:0.652472
# [394]	validation_0-logloss:0.652373
# [395]	validation_0-logloss:0.652293
# [396]	validation_0-logloss:0.652215
# [397]	validation_0-logloss:0.652112
# [398]	validation_0-logloss:0.652034
# [399]	validation_0-logloss:0.65194
# [400]	validation_0-logloss:0.651837
# [401]	validation_0-logloss:0.651774
# [402]	validation_0-logloss:0.651711
# [403]	validation_0-logloss:0.651634
# [404]	validation_0-logloss:0.651548
# [405]	validation_0-logloss:0.651451
# [406]	validation_0-logloss:0.651366
# [407]	validation_0-logloss:0.651279
# [408]	validation_0-logloss:0.651188
# [409]	validation_0-logloss:0.651084
# [410]	validation_0-logloss:0.651007
# [411]	validation_0-logloss:0.650965
# [412]	validation_0-logloss:0.650894
# [413]	validation_0-logloss:0.650796
# [414]	validation_0-logloss:0.650701
# [415]	validation_0-logloss:0.650615
# [416]	validation_0-logloss:0.650519
# [417]	validation_0-logloss:0.650441
# [418]	validation_0-logloss:0.650353
# [419]	validation_0-logloss:0.650264
# [420]	validation_0-logloss:0.6502
# [421]	validation_0-logloss:0.650148
# [422]	validation_0-logloss:0.650056
# [423]	validation_0-logloss:0.649934
# [424]	validation_0-logloss:0.649821
# [425]	validation_0-logloss:0.649739
# [426]	validation_0-logloss:0.649671
# [427]	validation_0-logloss:0.6496
# [428]	validation_0-logloss:0.649507
# [429]	validation_0-logloss:0.649395
# [430]	validation_0-logloss:0.649325
# [431]	validation_0-logloss:0.649226
# [432]	validation_0-logloss:0.64914
# [433]	validation_0-logloss:0.649036
# [434]	validation_0-logloss:0.648956
# [435]	validation_0-logloss:0.648878
# [436]	validation_0-logloss:0.64879
# [437]	validation_0-logloss:0.648722
# [438]	validation_0-logloss:0.648638
# [439]	validation_0-logloss:0.64855
# [440]	validation_0-logloss:0.648487
# [441]	validation_0-logloss:0.648408
# [442]	validation_0-logloss:0.648355
# [443]	validation_0-logloss:0.648275
# [444]	validation_0-logloss:0.648199
# [445]	validation_0-logloss:0.648105
# [446]	validation_0-logloss:0.64803
# [447]	validation_0-logloss:0.647956
# [448]	validation_0-logloss:0.647886
# [449]	validation_0-logloss:0.647796
# [450]	validation_0-logloss:0.6477
# [451]	validation_0-logloss:0.647605
# [452]	validation_0-logloss:0.647517
# [453]	validation_0-logloss:0.647452
# [454]	validation_0-logloss:0.647366
# [455]	validation_0-logloss:0.647299
# [456]	validation_0-logloss:0.647234
# [457]	validation_0-logloss:0.64717
# [458]	validation_0-logloss:0.647074
# [459]	validation_0-logloss:0.646999
# [460]	validation_0-logloss:0.646911
# [461]	validation_0-logloss:0.646816
# [462]	validation_0-logloss:0.646743
# [463]	validation_0-logloss:0.646684
# [464]	validation_0-logloss:0.646597
# [465]	validation_0-logloss:0.646532
# [466]	validation_0-logloss:0.646447
# [467]	validation_0-logloss:0.646363
# [468]	validation_0-logloss:0.646259
# [469]	validation_0-logloss:0.646185
# [470]	validation_0-logloss:0.646108
# [471]	validation_0-logloss:0.646041
# [472]	validation_0-logloss:0.645959
# [473]	validation_0-logloss:0.645903
# [474]	validation_0-logloss:0.645786
# [475]	validation_0-logloss:0.645715
# [476]	validation_0-logloss:0.645636
# [477]	validation_0-logloss:0.645582
# [478]	validation_0-logloss:0.645501
# [479]	validation_0-logloss:0.645395
# [480]	validation_0-logloss:0.645323
# [481]	validation_0-logloss:0.645229
# [482]	validation_0-logloss:0.645119
# [483]	validation_0-logloss:0.645047
# [484]	validation_0-logloss:0.64497
# [485]	validation_0-logloss:0.644879
# [486]	validation_0-logloss:0.644796
# [487]	validation_0-logloss:0.644712
# [488]	validation_0-logloss:0.64463
# [489]	validation_0-logloss:0.644568
# [490]	validation_0-logloss:0.644514
# [491]	validation_0-logloss:0.644443
# [492]	validation_0-logloss:0.64437
# [493]	validation_0-logloss:0.64431
# [494]	validation_0-logloss:0.644247
# [495]	validation_0-logloss:0.644194
# [496]	validation_0-logloss:0.644112
# [497]	validation_0-logloss:0.644025
# [498]	validation_0-logloss:0.643972
# [499]	validation_0-logloss:0.643889
# [500]	validation_0-logloss:0.643806
# [501]	validation_0-logloss:0.643704
# [502]	validation_0-logloss:0.643633
# [503]	validation_0-logloss:0.64358
# [504]	validation_0-logloss:0.643503
# [505]	validation_0-logloss:0.643461
# [506]	validation_0-logloss:0.643367
# [507]	validation_0-logloss:0.643298
# [508]	validation_0-logloss:0.64322
# [509]	validation_0-logloss:0.643146
# [510]	validation_0-logloss:0.643066
# [511]	validation_0-logloss:0.642987
# [512]	validation_0-logloss:0.642936
# [513]	validation_0-logloss:0.642856
# [514]	validation_0-logloss:0.642805
# [515]	validation_0-logloss:0.642729
# [516]	validation_0-logloss:0.642639
# [517]	validation_0-logloss:0.642536
# [518]	validation_0-logloss:0.642461
# [519]	validation_0-logloss:0.64238
# [520]	validation_0-logloss:0.642304
# [521]	validation_0-logloss:0.6422
# [522]	validation_0-logloss:0.642126
# [523]	validation_0-logloss:0.642042
# [524]	validation_0-logloss:0.642005
# [525]	validation_0-logloss:0.641908
# [526]	validation_0-logloss:0.641825
# [527]	validation_0-logloss:0.641788
# [528]	validation_0-logloss:0.641727
# [529]	validation_0-logloss:0.641648
# [530]	validation_0-logloss:0.64157
# [531]	validation_0-logloss:0.641508
# [532]	validation_0-logloss:0.641431
# [533]	validation_0-logloss:0.641349
# [534]	validation_0-logloss:0.641295
# [535]	validation_0-logloss:0.641224
# [536]	validation_0-logloss:0.641158
# [537]	validation_0-logloss:0.641108
# [538]	validation_0-logloss:0.641039
# [539]	validation_0-logloss:0.640971
# [540]	validation_0-logloss:0.640891
# [541]	validation_0-logloss:0.640791
# [542]	validation_0-logloss:0.640727
# [543]	validation_0-logloss:0.64065
# [544]	validation_0-logloss:0.640588
# [545]	validation_0-logloss:0.640511
# [546]	validation_0-logloss:0.640446
# [547]	validation_0-logloss:0.640363
# [548]	validation_0-logloss:0.640305
# [549]	validation_0-logloss:0.640232
# [550]	validation_0-logloss:0.640158
# [551]	validation_0-logloss:0.64009
# [552]	validation_0-logloss:0.640003
# [553]	validation_0-logloss:0.639939
# [554]	validation_0-logloss:0.639858
# [555]	validation_0-logloss:0.639783
# [556]	validation_0-logloss:0.639743
# [557]	validation_0-logloss:0.639673
# [558]	validation_0-logloss:0.639584
# [559]	validation_0-logloss:0.6395
# [639]	validation_0-logloss:0.633897
# [640]	validation_0-logloss:0.633814
# [641]	validation_0-logloss:0.633738
# [642]	validation_0-logloss:0.633652
# [643]	validation_0-logloss:0.633562
# [644]	validation_0-logloss:0.633501
# [645]	validation_0-logloss:0.633423
# [646]	validation_0-logloss:0.633359
# [647]	validation_0-logloss:0.633291
# [648]	validation_0-logloss:0.633199
# [649]	validation_0-logloss:0.633146
# [650]	validation_0-logloss:0.633081
# [651]	validation_0-logloss:0.633012
# [652]	validation_0-logloss:0.632936
# [653]	validation_0-logloss:0.632883
# [654]	validation_0-logloss:0.632838
# [655]	validation_0-logloss:0.632792
# [656]	validation_0-logloss:0.632716
# [657]	validation_0-logloss:0.63268
# [658]	validation_0-logloss:0.632621
# [659]	validation_0-logloss:0.632535
# [660]	validation_0-logloss:0.632488
# [661]	validation_0-logloss:0.632455
# [662]	validation_0-logloss:0.632396
# [663]	validation_0-logloss:0.632307
# [664]	validation_0-logloss:0.632225
# [665]	validation_0-logloss:0.632161
# [666]	validation_0-logloss:0.632108
# [667]	validation_0-logloss:0.632048
# [668]	validation_0-logloss:0.63196
# [669]	validation_0-logloss:0.631901
# [670]	validation_0-logloss:0.631873
# [671]	validation_0-logloss:0.631802
# [672]	validation_0-logloss:0.631712
# [673]	validation_0-logloss:0.631621
# [674]	validation_0-logloss:0.631555
# [675]	validation_0-logloss:0.631507
# [676]	validation_0-logloss:0.631468
# [677]	validation_0-logloss:0.631416
# [678]	validation_0-logloss:0.631371
# [679]	validation_0-logloss:0.63133
# [680]	validation_0-logloss:0.631269
# [681]	validation_0-logloss:0.631186
# [682]	validation_0-logloss:0.631094
# [683]	validation_0-logloss:0.631047
# [684]	validation_0-logloss:0.630977
# [685]	validation_0-logloss:0.63091
# [686]	validation_0-logloss:0.630851
# [687]	validation_0-logloss:0.630802
# [688]	validation_0-logloss:0.630743
# [689]	validation_0-logloss:0.630676
# [690]	validation_0-logloss:0.630615
# [691]	validation_0-logloss:0.630549
# [692]	validation_0-logloss:0.630499
# [693]	validation_0-logloss:0.630414
# [694]	validation_0-logloss:0.630355
# [695]	validation_0-logloss:0.630275
# [696]	validation_0-logloss:0.630216
# [697]	validation_0-logloss:0.630149
# [698]	validation_0-logloss:0.630094
# [699]	validation_0-logloss:0.630032
# [700]	validation_0-logloss:0.629941
# [701]	validation_0-logloss:0.629863
# [702]	validation_0-logloss:0.629808
# [703]	validation_0-logloss:0.629744
# [704]	validation_0-logloss:0.62969
# [705]	validation_0-logloss:0.629633
# [706]	validation_0-logloss:0.629555
# [707]	validation_0-logloss:0.629495
# [708]	validation_0-logloss:0.629448
# [709]	validation_0-logloss:0.629379
# [710]	validation_0-logloss:0.629301
# [711]	validation_0-logloss:0.629248
# [712]	validation_0-logloss:0.62918
# [713]	validation_0-logloss:0.62911
# [714]	validation_0-logloss:0.629026
# [715]	validation_0-logloss:0.628957
# [716]	validation_0-logloss:0.628891
# [717]	validation_0-logloss:0.628838
# [718]	validation_0-logloss:0.628771
# [719]	validation_0-logloss:0.628703
# [720]	validation_0-logloss:0.628625
# [721]	validation_0-logloss:0.628553
# [722]	validation_0-logloss:0.628518
# [723]	validation_0-logloss:0.628458
# [724]	validation_0-logloss:0.628409
# [725]	validation_0-logloss:0.628358
# [726]	validation_0-logloss:0.628295
# [727]	validation_0-logloss:0.628235
# [728]	validation_0-logloss:0.628169
# [729]	validation_0-logloss:0.628125
# [730]	validation_0-logloss:0.628079
# [731]	validation_0-logloss:0.628014
# [732]	validation_0-logloss:0.627951
# [733]	validation_0-logloss:0.627882
# [734]	validation_0-logloss:0.627781
# [735]	validation_0-logloss:0.627722
# [736]	validation_0-logloss:0.627658
# [737]	validation_0-logloss:0.627594
# [738]	validation_0-logloss:0.62753
# [739]	validation_0-logloss:0.627439
# [740]	validation_0-logloss:0.627379
# [741]	validation_0-logloss:0.627329
# [742]	validation_0-logloss:0.627261
# [743]	validation_0-logloss:0.627187
# [744]	validation_0-logloss:0.627117
# [745]	validation_0-logloss:0.627055
# [746]	validation_0-logloss:0.626999
# [747]	validation_0-logloss:0.626945
# [748]	validation_0-logloss:0.626879
# [749]	validation_0-logloss:0.626849
# [750]	validation_0-logloss:0.626786
# [751]	validation_0-logloss:0.62673
# [752]	validation_0-logloss:0.626661
# [753]	validation_0-logloss:0.626602
# [754]	validation_0-logloss:0.626559
# [755]	validation_0-logloss:0.626508
# [756]	validation_0-logloss:0.62644
# [757]	validation_0-logloss:0.626404
# [758]	validation_0-logloss:0.626363
# [759]	validation_0-logloss:0.626295
# [760]	validation_0-logloss:0.626258
# [761]	validation_0-logloss:0.626173
# [762]	validation_0-logloss:0.626108
# [763]	validation_0-logloss:0.626043
# [764]	validation_0-logloss:0.625961
# [765]	validation_0-logloss:0.625893
# [766]	validation_0-logloss:0.62584
# [767]	validation_0-logloss:0.625783
# [768]	validation_0-logloss:0.625746
# [769]	validation_0-logloss:0.625672
# [770]	validation_0-logloss:0.625602
# [771]	validation_0-logloss:0.625562
# [772]	validation_0-logloss:0.625477
# [773]	validation_0-logloss:0.625423
# [774]	validation_0-logloss:0.625367
# [775]	validation_0-logloss:0.625307
# [776]	validation_0-logloss:0.625235
# [777]	validation_0-logloss:0.625175
# [778]	validation_0-logloss:0.625135
# [779]	validation_0-logloss:0.625091
# [780]	validation_0-logloss:0.625025
# [781]	validation_0-logloss:0.62496
# [782]	validation_0-logloss:0.624876
# [783]	validation_0-logloss:0.624794
# [784]	validation_0-logloss:0.624747
# [785]	validation_0-logloss:0.624722
# [786]	validation_0-logloss:0.62466
# [787]	validation_0-logloss:0.624588
# [788]	validation_0-logloss:0.624532
# [789]	validation_0-logloss:0.624484
# [790]	validation_0-logloss:0.624424
# [791]	validation_0-logloss:0.624357
# [792]	validation_0-logloss:0.624321
# [793]	validation_0-logloss:0.624283
# [794]	validation_0-logloss:0.624226
# [795]	validation_0-logloss:0.624163
# [796]	validation_0-logloss:0.6241
# [797]	validation_0-logloss:0.624055
# [798]	validation_0-logloss:0.624002
# [799]	validation_0-logloss:0.623951
# [800]	validation_0-logloss:0.623931
# [801]	validation_0-logloss:0.623887
# [802]	validation_0-logloss:0.623848
# [803]	validation_0-logloss:0.623783
# [804]	validation_0-logloss:0.623735
# [805]	validation_0-logloss:0.62367
# [806]	validation_0-logloss:0.623633
# [807]	validation_0-logloss:0.623563
# [808]	validation_0-logloss:0.623519
# [809]	validation_0-logloss:0.623481
# [810]	validation_0-logloss:0.623393
# [811]	validation_0-logloss:0.623322
# [812]	validation_0-logloss:0.623245
# [813]	validation_0-logloss:0.623185
# [814]	validation_0-logloss:0.623143
# [815]	validation_0-logloss:0.623069
# [816]	validation_0-logloss:0.623008
# [817]	validation_0-logloss:0.622951
# [818]	validation_0-logloss:0.622898
# [819]	validation_0-logloss:0.622857
# [820]	validation_0-logloss:0.62281
# [821]	validation_0-logloss:0.622754
# [822]	validation_0-logloss:0.622693
# [823]	validation_0-logloss:0.622613
# [824]	validation_0-logloss:0.622561
# [825]	validation_0-logloss:0.62253
# [826]	validation_0-logloss:0.622493
# [827]	validation_0-logloss:0.622436
# [828]	validation_0-logloss:0.622407
# [829]	validation_0-logloss:0.622374
# [830]	validation_0-logloss:0.622309
# [831]	validation_0-logloss:0.622253
# [832]	validation_0-logloss:0.622172
# [833]	validation_0-logloss:0.622108
# [834]	validation_0-logloss:0.622038
# [835]	validation_0-logloss:0.621981
# [836]	validation_0-logloss:0.62193
# [837]	validation_0-logloss:0.621874
# [838]	validation_0-logloss:0.621818
# [839]	validation_0-logloss:0.621765
# [840]	validation_0-logloss:0.621718
# [841]	validation_0-logloss:0.621667
# [842]	validation_0-logloss:0.621611
# [843]	validation_0-logloss:0.62159
# [844]	validation_0-logloss:0.621559
# [845]	validation_0-logloss:0.621516
# [846]	validation_0-logloss:0.621468
# [847]	validation_0-logloss:0.621422
# [848]	validation_0-logloss:0.621372
# [849]	validation_0-logloss:0.621321
# [850]	validation_0-logloss:0.621277
# [851]	validation_0-logloss:0.621228
# [852]	validation_0-logloss:0.621165
# [853]	validation_0-logloss:0.621132
# [854]	validation_0-logloss:0.621094
# [855]	validation_0-logloss:0.621036
# [856]	validation_0-logloss:0.62096
# [857]	validation_0-logloss:0.62092
# [858]	validation_0-logloss:0.620867
# [859]	validation_0-logloss:0.620806
# [860]	validation_0-logloss:0.620756
# [861]	validation_0-logloss:0.620708
# [862]	validation_0-logloss:0.620674
# [863]	validation_0-logloss:0.620629
# [864]	validation_0-logloss:0.620595
# [865]	validation_0-logloss:0.620537
# [866]	validation_0-logloss:0.620471
# [867]	validation_0-logloss:0.620412
# [868]	validation_0-logloss:0.620334
# [869]	validation_0-logloss:0.620281
# [870]	validation_0-logloss:0.620238
# [871]	validation_0-logloss:0.620176
# [872]	validation_0-logloss:0.620127
# [873]	validation_0-logloss:0.620069
# [874]	validation_0-logloss:0.620012
# [875]	validation_0-logloss:0.619948
# [876]	validation_0-logloss:0.619888
# [877]	validation_0-logloss:0.619844
# [878]	validation_0-logloss:0.619794
# [3618]	validation_0-logloss:0.573756
# [3619]	validation_0-logloss:0.573755
# [3620]	validation_0-logloss:0.573739
# [3621]	validation_0-logloss:0.573749
# [3622]	validation_0-logloss:0.573748
# [3623]	validation_0-logloss:0.573745
# [3624]	validation_0-logloss:0.57373
# [3625]	validation_0-logloss:0.573722
# [3626]	validation_0-logloss:0.573719
# [3627]	validation_0-logloss:0.573707
# [3628]	validation_0-logloss:0.573686
# [3629]	validation_0-logloss:0.573703
# [3630]	validation_0-logloss:0.573699
# [3631]	validation_0-logloss:0.573701
# [3632]	validation_0-logloss:0.573684
# [3633]	validation_0-logloss:0.573683
# [3634]	validation_0-logloss:0.573689
# [3635]	validation_0-logloss:0.573686
# [3636]	validation_0-logloss:0.573703
# [3637]	validation_0-logloss:0.573703
# [3638]	validation_0-logloss:0.573697
# [3639]	validation_0-logloss:0.573694
# [3640]	validation_0-logloss:0.573688
# [3641]	validation_0-logloss:0.573683
# [3642]	validation_0-logloss:0.573701
# [3643]	validation_0-logloss:0.573711
# [3644]	validation_0-logloss:0.573713
# [3645]	validation_0-logloss:0.573706
# [3646]	validation_0-logloss:0.573718
# [3647]	validation_0-logloss:0.573705
# [3648]	validation_0-logloss:0.573691
# [3649]	validation_0-logloss:0.573704
# [3650]	validation_0-logloss:0.573728
# [3651]	validation_0-logloss:0.573729
# [3652]	validation_0-logloss:0.573728
# [3653]	validation_0-logloss:0.573717
# [3654]	validation_0-logloss:0.573714
# [3655]	validation_0-logloss:0.573711
# [3656]	validation_0-logloss:0.573719
# [3657]	validation_0-logloss:0.5737
# [3658]	validation_0-logloss:0.573697
# [3659]	validation_0-logloss:0.573694
# [3660]	validation_0-logloss:0.573696
# [3661]	validation_0-logloss:0.57368
# [3662]	validation_0-logloss:0.57368
# [3663]	validation_0-logloss:0.573693
# [3664]	validation_0-logloss:0.573675
# [3665]	validation_0-logloss:0.573658
# [3666]	validation_0-logloss:0.573649
# [3667]	validation_0-logloss:0.573647
# [3668]	validation_0-logloss:0.573658
# [3669]	validation_0-logloss:0.573646
# [3670]	validation_0-logloss:0.573678
# [3671]	validation_0-logloss:0.573675
# [3672]	validation_0-logloss:0.573686
# [3673]	validation_0-logloss:0.573706
# [3674]	validation_0-logloss:0.5737
# [3675]	validation_0-logloss:0.573701
# [3676]	validation_0-logloss:0.573704
# [3677]	validation_0-logloss:0.573686
# [3678]	validation_0-logloss:0.573688
# [3679]	validation_0-logloss:0.573671
# [3680]	validation_0-logloss:0.573687
# [3681]	validation_0-logloss:0.573681
# [3682]	validation_0-logloss:0.573669
# [3683]	validation_0-logloss:0.573662
# [3684]	validation_0-logloss:0.573661
# [3685]	validation_0-logloss:0.573674
# [3686]	validation_0-logloss:0.573671
# [3687]	validation_0-logloss:0.573667
# [3688]	validation_0-logloss:0.573666
# [3689]	validation_0-logloss:0.573686
# [3690]	validation_0-logloss:0.57369
# [3691]	validation_0-logloss:0.573694
# [3692]	validation_0-logloss:0.573697
# [3693]	validation_0-logloss:0.573706
# [3694]	validation_0-logloss:0.573709
# [3695]	validation_0-logloss:0.573698
# [3696]	validation_0-logloss:0.573696
# [3697]	validation_0-logloss:0.573694
# [3698]	validation_0-logloss:0.573674
# [3699]	validation_0-logloss:0.573689
# [3700]	validation_0-logloss:0.573688
# [3701]	validation_0-logloss:0.573673
# [3702]	validation_0-logloss:0.57367
# [3703]	validation_0-logloss:0.573672
# [3704]	validation_0-logloss:0.573675
# [3705]	validation_0-logloss:0.573685
# [3706]	validation_0-logloss:0.573672
# [3707]	validation_0-logloss:0.573672
# [3708]	validation_0-logloss:0.573668
# [3709]	validation_0-logloss:0.573653
# [3710]	validation_0-logloss:0.573644
# [3711]	validation_0-logloss:0.573641
# [3712]	validation_0-logloss:0.573635
# [3713]	validation_0-logloss:0.573641
# [3714]	validation_0-logloss:0.573645
# [3715]	validation_0-logloss:0.573645
# [3716]	validation_0-logloss:0.573643
# [3717]	validation_0-logloss:0.573633
# [3718]	validation_0-logloss:0.573643
# [3719]	validation_0-logloss:0.573637
# [3720]	validation_0-logloss:0.573635
# [3721]	validation_0-logloss:0.573656
# [3722]	validation_0-logloss:0.573651
# [3723]	validation_0-logloss:0.573653
# [3724]	validation_0-logloss:0.573637
# [3725]	validation_0-logloss:0.573638
# [3726]	validation_0-logloss:0.573634
# [3727]	validation_0-logloss:0.573642
# [3728]	validation_0-logloss:0.573616
# [3729]	validation_0-logloss:0.573623
# [3730]	validation_0-logloss:0.573614
# [3731]	validation_0-logloss:0.573609
# [3732]	validation_0-logloss:0.573594
# [3733]	validation_0-logloss:0.573593
# [3734]	validation_0-logloss:0.573582
# [3735]	validation_0-logloss:0.573578
# [3736]	validation_0-logloss:0.573572
# [3737]	validation_0-logloss:0.573563
# [3738]	validation_0-logloss:0.573568
# [3739]	validation_0-logloss:0.573559
# [3740]	validation_0-logloss:0.573562
# [3741]	validation_0-logloss:0.57358
# [3742]	validation_0-logloss:0.573567
# [3743]	validation_0-logloss:0.573573
# [3744]	validation_0-logloss:0.573566
# [3745]	validation_0-logloss:0.573574
# [3746]	validation_0-logloss:0.573581
# [3747]	validation_0-logloss:0.573576
# [3748]	validation_0-logloss:0.573592
# [3749]	validation_0-logloss:0.573598
# [3750]	validation_0-logloss:0.573603
# [3751]	validation_0-logloss:0.573592
# [3752]	validation_0-logloss:0.57359
# [3753]	validation_0-logloss:0.573591
# [3754]	validation_0-logloss:0.573601
# [3755]	validation_0-logloss:0.573611
# [3756]	validation_0-logloss:0.573605
# [3757]	validation_0-logloss:0.573596
# [3758]	validation_0-logloss:0.573587
# [3759]	validation_0-logloss:0.573596
# [3760]	validation_0-logloss:0.573578
# [3761]	validation_0-logloss:0.573574
# [3762]	validation_0-logloss:0.573563
# [3763]	validation_0-logloss:0.573562
# [3764]	validation_0-logloss:0.573564
# [3765]	validation_0-logloss:0.573562
# [3766]	validation_0-logloss:0.573557
# [3767]	validation_0-logloss:0.573559
# [3768]	validation_0-logloss:0.573555
# [3769]	validation_0-logloss:0.573568
# [3770]	validation_0-logloss:0.573553
# [3771]	validation_0-logloss:0.573546
# [3772]	validation_0-logloss:0.573539
# [3773]	validation_0-logloss:0.573545
# [3774]	validation_0-logloss:0.573543
# [3775]	validation_0-logloss:0.573542
# [3776]	validation_0-logloss:0.573557
# [3777]	validation_0-logloss:0.573542
# [3778]	validation_0-logloss:0.573559
# [3779]	validation_0-logloss:0.573567
# [3780]	validation_0-logloss:0.573575
# [3781]	validation_0-logloss:0.573578
# [3782]	validation_0-logloss:0.573577
# [3783]	validation_0-logloss:0.573562
# [3784]	validation_0-logloss:0.573568
# [3785]	validation_0-logloss:0.573584
# [3786]	validation_0-logloss:0.573578
# [3787]	validation_0-logloss:0.573575
# [3788]	validation_0-logloss:0.573577
# [3789]	validation_0-logloss:0.573585
# [3790]	validation_0-logloss:0.573588
# [3791]	validation_0-logloss:0.573574
# [3792]	validation_0-logloss:0.573578
# [3793]	validation_0-logloss:0.573582
# [3794]	validation_0-logloss:0.573588
# [3795]	validation_0-logloss:0.573594
# [3796]	validation_0-logloss:0.573591
# [3797]	validation_0-logloss:0.573593
# [3798]	validation_0-logloss:0.573606
# [3799]	validation_0-logloss:0.573611
# [3800]	validation_0-logloss:0.573607
# [3801]	validation_0-logloss:0.573623
# [3802]	validation_0-logloss:0.573626
# [3803]	validation_0-logloss:0.573616
# [3804]	validation_0-logloss:0.573617
# [3805]	validation_0-logloss:0.573604
# [3806]	validation_0-logloss:0.573594
# [3807]	validation_0-logloss:0.573591
# [3808]	validation_0-logloss:0.573588
# [3809]	validation_0-logloss:0.573583
# [3810]	validation_0-logloss:0.573586
# [3811]	validation_0-logloss:0.573568
# [3812]	validation_0-logloss:0.57357
# [3813]	validation_0-logloss:0.573565
# [3814]	validation_0-logloss:0.573562
# [3815]	validation_0-logloss:0.573566
# [3816]	validation_0-logloss:0.57357
# [3817]	validation_0-logloss:0.573578
# [3818]	validation_0-logloss:0.573585
# [3819]	validation_0-logloss:0.57358
# [3820]	validation_0-logloss:0.573583
# [3821]	validation_0-logloss:0.573585
# [3822]	validation_0-logloss:0.573597
# [3823]	validation_0-logloss:0.5736
# [3824]	validation_0-logloss:0.573589
# [3825]	validation_0-logloss:0.573593
# [3826]	validation_0-logloss:0.573582
# [3827]	validation_0-logloss:0.573578
# [3828]	validation_0-logloss:0.573581
# [3829]	validation_0-logloss:0.573568
# [3830]	validation_0-logloss:0.573569
# [3831]	validation_0-logloss:0.573577
# [3832]	validation_0-logloss:0.573567
# [3833]	validation_0-logloss:0.573585
# [3834]	validation_0-logloss:0.573582
# [3835]	validation_0-logloss:0.573578
# [3836]	validation_0-logloss:0.573571
# [3837]	validation_0-logloss:0.57358
# [3838]	validation_0-logloss:0.573583
# [3839]	validation_0-logloss:0.573589
# [3840]	validation_0-logloss:0.573572
# [3841]	validation_0-logloss:0.573564
# [3842]	validation_0-logloss:0.573567
# [3843]	validation_0-logloss:0.573573
# [3844]	validation_0-logloss:0.573569
# [3845]	validation_0-logloss:0.57358
# [3846]	validation_0-logloss:0.573595
# [3847]	validation_0-logloss:0.573608
# [3848]	validation_0-logloss:0.573623
# [3849]	validation_0-logloss:0.573619
# [3850]	validation_0-logloss:0.573608
# [3851]	validation_0-logloss:0.573596
# [3852]	validation_0-logloss:0.573596
# [3853]	validation_0-logloss:0.573606
# [3854]	validation_0-logloss:0.573617
# [3855]	validation_0-logloss:0.573603
# [3856]	validation_0-logloss:0.573593
# [3857]	validation_0-logloss:0.573585
# [3858]	validation_0-logloss:0.573601
# [3859]	validation_0-logloss:0.573588
# [3860]	validation_0-logloss:0.57358
# [3861]	validation_0-logloss:0.573574
# [3862]	validation_0-logloss:0.573576
# [3863]	validation_0-logloss:0.573577
# [3864]	validation_0-logloss:0.573576
# [3865]	validation_0-logloss:0.573575
# [3866]	validation_0-logloss:0.573572
# [3867]	validation_0-logloss:0.573577
# [3868]	validation_0-logloss:0.573567
# [3869]	validation_0-logloss:0.57356
# [3870]	validation_0-logloss:0.573568
# [3871]	validation_0-logloss:0.573574
# [3872]	validation_0-logloss:0.57357
# [3873]	validation_0-logloss:0.573567
# [3874]	validation_0-logloss:0.573565
# [3875]	validation_0-logloss:0.573566
# [3876]	validation_0-logloss:0.573577
# [3877]	validation_0-logloss:0.573567
# [3878]	validation_0-logloss:0.573575
# [3879]	validation_0-logloss:0.573584
# [3880]	validation_0-logloss:0.573575
# [3881]	validation_0-logloss:0.57357
# [3882]	validation_0-logloss:0.573566
# [3883]	validation_0-logloss:0.57357
# [3884]	validation_0-logloss:0.573578
# [3885]	validation_0-logloss:0.573581
# [3886]	validation_0-logloss:0.573579
# [3887]	validation_0-logloss:0.573572
# [3888]	validation_0-logloss:0.573598
# [3889]	validation_0-logloss:0.573601
# [3890]	validation_0-logloss:0.57361
# [3891]	validation_0-logloss:0.573602
# [3892]	validation_0-logloss:0.573596
# [3893]	validation_0-logloss:0.573595
# [3894]	validation_0-logloss:0.573593
# [3895]	validation_0-logloss:0.573604
# [3896]	validation_0-logloss:0.573605
# [3897]	validation_0-logloss:0.573607
# [3898]	validation_0-logloss:0.573618
# [3899]	validation_0-logloss:0.573621
# [3900]	validation_0-logloss:0.573606
# [3901]	validation_0-logloss:0.573608
# [3902]	validation_0-logloss:0.573609
# [3903]	validation_0-logloss:0.573616
# [3904]	validation_0-logloss:0.573617
# [3905]	validation_0-logloss:0.573609
# [3906]	validation_0-logloss:0.573609
# [3907]	validation_0-logloss:0.573619
# [3908]	validation_0-logloss:0.573604
# [3909]	validation_0-logloss:0.573603
# [3910]	validation_0-logloss:0.573603
# [3911]	validation_0-logloss:0.573606
# [3912]	validation_0-logloss:0.573636
# [3913]	validation_0-logloss:0.573651
# [3914]	validation_0-logloss:0.573645
# [3915]	validation_0-logloss:0.573635
# [3916]	validation_0-logloss:0.57363
# [3917]	validation_0-logloss:0.573624
# [3918]	validation_0-logloss:0.573633
# [3919]	validation_0-logloss:0.573617
# [3920]	validation_0-logloss:0.573624
# [3921]	validation_0-logloss:0.573617
# [3922]	validation_0-logloss:0.573612
# [3923]	validation_0-logloss:0.573616
# [3924]	validation_0-logloss:0.57361
# [3925]	validation_0-logloss:0.573607
# [3926]	validation_0-logloss:0.573607
# [3927]	validation_0-logloss:0.57361
# [3928]	validation_0-logloss:0.573607
# [3929]	validation_0-logloss:0.573606
# [3930]	validation_0-logloss:0.573611
# [3931]	validation_0-logloss:0.573623
# [3932]	validation_0-logloss:0.573633
# [3933]	validation_0-logloss:0.573638
# [3934]	validation_0-logloss:0.57363
# [3935]	validation_0-logloss:0.573638
# [3936]	validation_0-logloss:0.573619
# [3937]	validation_0-logloss:0.573599
# [3938]	validation_0-logloss:0.573603
# [3939]	validation_0-logloss:0.573599
# [3940]	validation_0-logloss:0.57359
# [3941]	validation_0-logloss:0.573593
# [3942]	validation_0-logloss:0.573601
# [3943]	validation_0-logloss:0.573596
# [3944]	validation_0-logloss:0.573595
# [3945]	validation_0-logloss:0.573591
# [3946]	validation_0-logloss:0.573606
# [3947]	validation_0-logloss:0.573601
# [3948]	validation_0-logloss:0.573609
# [3949]	validation_0-logloss:0.573592
# [3950]	validation_0-logloss:0.573591
# [3951]	validation_0-logloss:0.573603
# [3952]	validation_0-logloss:0.573598
# [3953]	validation_0-logloss:0.573609
# [3954]	validation_0-logloss:0.573596
# [3955]	validation_0-logloss:0.573606
# [3956]	validation_0-logloss:0.573622
# [3957]	validation_0-logloss:0.573623
# [3958]	validation_0-logloss:0.573618
# [3959]	validation_0-logloss:0.573612
# [3960]	validation_0-logloss:0.573597
# [3961]	validation_0-logloss:0.573599
# [3962]	validation_0-logloss:0.573604
# [3963]	validation_0-logloss:0.573606
# [3964]	validation_0-logloss:0.573605
# [3965]	validation_0-logloss:0.573622
# [3966]	validation_0-logloss:0.573616
# [3967]	validation_0-logloss:0.573614
# [3968]	validation_0-logloss:0.573627
# [3969]	validation_0-logloss:0.573636
# [3970]	validation_0-logloss:0.573634
# [3971]	validation_0-logloss:0.573647
# [3972]	validation_0-logloss:0.57365
# [3973]	validation_0-logloss:0.57366
# [3974]	validation_0-logloss:0.573657
# [3975]	validation_0-logloss:0.573655
# [3976]	validation_0-logloss:0.57364
# [3977]	validation_0-logloss:0.573626
# [3978]	validation_0-logloss:0.573623
# [3979]	validation_0-logloss:0.573605
# [3980]	validation_0-logloss:0.573607
# [3981]	validation_0-logloss:0.573594
# [3982]	validation_0-logloss:0.573602
# [3983]	validation_0-logloss:0.573587
# [3984]	validation_0-logloss:0.573586
# [3985]	validation_0-logloss:0.573586
# [3986]	validation_0-logloss:0.573582
# [3987]	validation_0-logloss:0.573568
# [3988]	validation_0-logloss:0.573585
# [3989]	validation_0-logloss:0.573584
# [3990]	validation_0-logloss:0.573583
# [3991]	validation_0-logloss:0.573587
# [3992]	validation_0-logloss:0.57359
# [3993]	validation_0-logloss:0.573597
# [3994]	validation_0-logloss:0.573612
# [3995]	validation_0-logloss:0.573625
# [3996]	validation_0-logloss:0.573618
# [3997]	validation_0-logloss:0.573628
# [3998]	validation_0-logloss:0.573625
# [3999]	validation_0-logloss:0.573616
# [4000]	validation_0-logloss:0.573616
# [4001]	validation_0-logloss:0.573611
# [4002]	validation_0-logloss:0.573619
# [4003]	validation_0-logloss:0.57361
# [4004]	validation_0-logloss:0.573606
# [4005]	validation_0-logloss:0.573614
# [4006]	validation_0-logloss:0.573601
# [4007]	validation_0-logloss:0.573615
# [4008]	validation_0-logloss:0.573621
# [4009]	validation_0-logloss:0.573631
# [4010]	validation_0-logloss:0.573646
# [4011]	validation_0-logloss:0.57365
# [4012]	validation_0-logloss:0.573648
# [4013]	validation_0-logloss:0.573657
# [4014]	validation_0-logloss:0.573646
# [4015]	validation_0-logloss:0.573649
# [4016]	validation_0-logloss:0.57366
# [4017]	validation_0-logloss:0.573659
# [4018]	validation_0-logloss:0.573666
# [4019]	validation_0-logloss:0.57367
# [4020]	validation_0-logloss:0.57367
# [4021]	validation_0-logloss:0.573676
# [4022]	validation_0-logloss:0.573675
# Stopping. Best iteration:
# [3772]	validation_0-logloss:0.573539
#
#                                  id    cancer
# 0  026470d51482c93efc18b9803159c960  0.549763
# 1  031b7ec4fe96a3b035a8196264a8c8c3  0.445919
# 2  03bd22ed5858039af223c04993e9eb22  0.405529
# 3  06a90409e4fcea3e634748b967993531  0.218883
# 4  07b1defcfae5873ee1f03c90255eb170  0.312625

# %%
df = pd.read_csv('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1_sample_submission.csv')

#filter(lambda patient_npy: ".npy" in patient_npy, )
x = np.array([np.mean(np.load('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1/%s.npy' % str(id)), axis=0) for id in df['id'].tolist()])

# %%
def data_overview():
    patients_folder_path = glob.glob('/media/yuens/WIN10-ENTERTENMENT/Kaggle/DSB2017/stage1/*')
    print("len(patients_folder_path):{0}".format(len(patients_folder_path)))
    for idx in xrange(len(patients_folder_path[:10])):
        print(idx, patients_folder_path[idx]) 
    
    valid_pathients_folder_path = filter(lambda p: ".npy" not in p, patients_folder_path)
    extracted_patients_npy_folder_path = filter(lambda p: ".npy" in p, patients_folder_path)
    extracted_patients_folder_path = map(lambda p: p.replace(".npy", ""), extracted_patients_npy_folder_path)
    unextracted_patients_folder_path = filter(lambda p: p not in extracted_patients_folder_path, valid_pathients_folder_path)
    print("len(valid_pathients_folder_path):{0}".format(len(valid_pathients_folder_path)))
    for idx in xrange(len(valid_pathients_folder_path[:10])):
        print(idx, valid_pathients_folder_path[idx]) 
    
    print("len(unextracted_patients_folder_path):{0}".format(len(unextracted_patients_folder_path)))
    for idx in xrange(len(unextracted_patients_folder_path[:10])):
        print(idx, unextracted_patients_folder_path[idx])
        
        
    print("len(extracted_patients_folder_path):{0}".format(len(extracted_patients_folder_path)))
    for idx in xrange(len(extracted_patients_folder_path[:10])):
        print(idx, extracted_patients_folder_path[idx])
    
    for idx in xrange(len(unextracted_patients_folder_path)):
        folder_path = unextracted_patients_folder_path[idx]
        batch = get_data_id(folder_path)
        feats = net.predict(batch)
        print(idx,feats.shape)
        np.save(folder_path, feats)
